# %%
from spineq.optimise import optimise, calc_oa_weights
from spineq.plotting import plot_oa_weights, plot_optimisation_result

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 17:37:31: failed to import boto3, continuing.

# %%
n_sensors = 20
theta = 500

# colour scale range
vmin = 0
vmax = 0.01

# %% [markdown]
# ## Total Population Only

# %%
age_weights = 1
population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

plot_oa_weights(weights, title="Weights: OA Total Residential Population",
                vmin=vmin, vmax=vmax)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

plot_optimisation_result(result)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 20 ... satisfaction = 0.04
# Placing sensor 2 out of 20 ... satisfaction = 0.08
# Placing sensor 3 out of 20 ... satisfaction = 0.10
# Placing sensor 4 out of 20 ... satisfaction = 0.12
# Placing sensor 5 out of 20 ... satisfaction = 0.15
# Placing sensor 6 out of 20 ... satisfaction = 0.17
# Placing sensor 7 out of 20 ... satisfaction = 0.19
# Placing sensor 8 out of 20 ... satisfaction = 0.21
# Placing sensor 9 out of 20 ... satisfaction = 0.22
# Placing sensor 10 out of 20 ... satisfaction = 0.23
# Placing sensor 11 out of 20 ... satisfaction = 0.24
# Placing sensor 12 out of 20 ... satisfaction = 0.26
# Placing sensor 13 out of 20 ... satisfaction = 0.27
# Placing sensor 14 out of 20 ... satisfaction = 0.28
# Placing sensor 15 out of 20 ... satisfaction = 0.29
# Placing sensor 16 out of 20 ... satisfaction = 0.30
# Placing sensor 17 out of 20 ... satisfaction = 0.31
# Placing sensor 18 out of 20 ... satisfaction = 0.32
# Placing sensor 19 out of 20 ... satisfaction = 0.33
# Placing sensor 20 out of 20 ... satisfaction = 0.34

# %% [markdown]
# ## Place of Work Only
#
# NB: Does using population weighted centroid make sense for workplace? Only alternative is to use OA (non-weighted) centroid. More complex for optimisation to use different locations for each one.

# %%
age_weights = 1
population_weight = 0
workplace_weight = 1

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

plot_oa_weights(weights, title="Weights: Number of Workers in OA",
                vmin=vmin, vmax=vmax)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

plot_optimisation_result(result)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 20 ... satisfaction = 0.16
# Placing sensor 2 out of 20 ... satisfaction = 0.23
# Placing sensor 3 out of 20 ... satisfaction = 0.27
# Placing sensor 4 out of 20 ... satisfaction = 0.32
# Placing sensor 5 out of 20 ... satisfaction = 0.36
# Placing sensor 6 out of 20 ... satisfaction = 0.39
# Placing sensor 7 out of 20 ... satisfaction = 0.42
# Placing sensor 8 out of 20 ... satisfaction = 0.45
# Placing sensor 9 out of 20 ... satisfaction = 0.47
# Placing sensor 10 out of 20 ... satisfaction = 0.48
# Placing sensor 11 out of 20 ... satisfaction = 0.50
# Placing sensor 12 out of 20 ... satisfaction = 0.51
# Placing sensor 13 out of 20 ... satisfaction = 0.53
# Placing sensor 14 out of 20 ... satisfaction = 0.54
# Placing sensor 15 out of 20 ... satisfaction = 0.55
# Placing sensor 16 out of 20 ... satisfaction = 0.56
# Placing sensor 17 out of 20 ... satisfaction = 0.57
# Placing sensor 18 out of 20 ... satisfaction = 0.59
# Placing sensor 19 out of 20 ... satisfaction = 0.60
# Placing sensor 20 out of 20 ... satisfaction = 0.61

# %% [markdown]
# ## Children <12 Years Old Only

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index < 12] = 1

population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

plot_oa_weights(weights, title="Weights: Children <11 Years Old",
                vmin=vmin, vmax=vmax)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

plot_optimisation_result(result)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 20 ... satisfaction = 0.06
# Placing sensor 2 out of 20 ... satisfaction = 0.09
# Placing sensor 3 out of 20 ... satisfaction = 0.11
# Placing sensor 4 out of 20 ... satisfaction = 0.14
# Placing sensor 5 out of 20 ... satisfaction = 0.16
# Placing sensor 6 out of 20 ... satisfaction = 0.18
# Placing sensor 7 out of 20 ... satisfaction = 0.20
# Placing sensor 8 out of 20 ... satisfaction = 0.22
# Placing sensor 9 out of 20 ... satisfaction = 0.23
# Placing sensor 10 out of 20 ... satisfaction = 0.25
# Placing sensor 11 out of 20 ... satisfaction = 0.26
# Placing sensor 12 out of 20 ... satisfaction = 0.27
# Placing sensor 13 out of 20 ... satisfaction = 0.29
# Placing sensor 14 out of 20 ... satisfaction = 0.30
# Placing sensor 15 out of 20 ... satisfaction = 0.31
# Placing sensor 16 out of 20 ... satisfaction = 0.32
# Placing sensor 17 out of 20 ... satisfaction = 0.33
# Placing sensor 18 out of 20 ... satisfaction = 0.34
# Placing sensor 19 out of 20 ... satisfaction = 0.35
# Placing sensor 20 out of 20 ... satisfaction = 0.36

# %% [markdown]
# ## Adults >65 Only

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index > 65] = 1

population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

plot_oa_weights(weights, title="Weights: Adults >65 Years Old",
                vmin=vmin, vmax=vmax)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

plot_optimisation_result(result)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 20 ... satisfaction = 0.03
# Placing sensor 2 out of 20 ... satisfaction = 0.06
# Placing sensor 3 out of 20 ... satisfaction = 0.08
# Placing sensor 4 out of 20 ... satisfaction = 0.11
# Placing sensor 5 out of 20 ... satisfaction = 0.13
# Placing sensor 6 out of 20 ... satisfaction = 0.14
# Placing sensor 7 out of 20 ... satisfaction = 0.16
# Placing sensor 8 out of 20 ... satisfaction = 0.18
# Placing sensor 9 out of 20 ... satisfaction = 0.19
# Placing sensor 10 out of 20 ... satisfaction = 0.21
# Placing sensor 11 out of 20 ... satisfaction = 0.22
# Placing sensor 12 out of 20 ... satisfaction = 0.23
# Placing sensor 13 out of 20 ... satisfaction = 0.25
# Placing sensor 14 out of 20 ... satisfaction = 0.26
# Placing sensor 15 out of 20 ... satisfaction = 0.27
# Placing sensor 16 out of 20 ... satisfaction = 0.28
# Placing sensor 17 out of 20 ... satisfaction = 0.29
# Placing sensor 18 out of 20 ... satisfaction = 0.30
# Placing sensor 19 out of 20 ... satisfaction = 0.31
# Placing sensor 20 out of 20 ... satisfaction = 0.32

# %% [markdown]
# ## Adults >65 Only

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index < 18] = 5
age_weights[age_weights.index < 12] = 10
age_weights[age_weights.index > 65] = 2
age_weights[age_weights.index > 75] = 5

plt.plot(age_weights)
plt.xlabel("Age")
plt.ylabel("Weight")

population_weight = 0.5
workplace_weight = 0.5

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

plot_oa_weights(weights, title="50% Residential, 50% Workplace, Increased Weight Children & Elderly",
                vmin=vmin, vmax=vmax)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

plot_optimisation_result(result)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 20 ... satisfaction = 0.09
# Placing sensor 2 out of 20 ... satisfaction = 0.12
# Placing sensor 3 out of 20 ... satisfaction = 0.15
# Placing sensor 4 out of 20 ... satisfaction = 0.19
# Placing sensor 5 out of 20 ... satisfaction = 0.21
# Placing sensor 6 out of 20 ... satisfaction = 0.23
# Placing sensor 7 out of 20 ... satisfaction = 0.25
# Placing sensor 8 out of 20 ... satisfaction = 0.27
# Placing sensor 9 out of 20 ... satisfaction = 0.29
# Placing sensor 10 out of 20 ... satisfaction = 0.30
# Placing sensor 11 out of 20 ... satisfaction = 0.32
# Placing sensor 12 out of 20 ... satisfaction = 0.33
# Placing sensor 13 out of 20 ... satisfaction = 0.34
# Placing sensor 14 out of 20 ... satisfaction = 0.36
# Placing sensor 15 out of 20 ... satisfaction = 0.37
# Placing sensor 16 out of 20 ... satisfaction = 0.38
# Placing sensor 17 out of 20 ... satisfaction = 0.39
# Placing sensor 18 out of 20 ... satisfaction = 0.40
# Placing sensor 19 out of 20 ... satisfaction = 0.41
# Placing sensor 20 out of 20 ... satisfaction = 0.41
