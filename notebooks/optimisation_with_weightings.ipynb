# %%
from spineq.optimise import optimise, calc_oa_weights
from spineq.plotting import plot_oa_weights, plot_optimisation_result

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
os.getcwd()
NB_DIR = "/Users/jroberts/GitHub/spatial-inequality/notebooks"
PLOT_DIR = NB_DIR + "/../data/img/pop_workplace_weight"
os.makedirs(PLOT_DIR, exist_ok=True)

# %%
n_sensors = 60
theta = 500

# colour scale range
vmin = 0
vmax = 0.01

# save (and overwrite) plots?
save = False

# %% [markdown]
# ## Total Population Only

# %%
age_weights = 1
population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/totalpop_weights.png"
else:
    save_path = None

plot_oa_weights(weights, title="Weights: OA Total Residential Population",
                vmin=vmin, vmax=vmax,
                save_path=save_path)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/totalpop_opt.png"
else:
    save_path = None

plot_optimisation_result(result, save_path=save_path)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 60 ... coverage = 0.04
# Placing sensor 2 out of 60 ... coverage = 0.08
# Placing sensor 3 out of 60 ... coverage = 0.10
# Placing sensor 4 out of 60 ... coverage = 0.12
# Placing sensor 5 out of 60 ... coverage = 0.15
# Placing sensor 6 out of 60 ... coverage = 0.17
# Placing sensor 7 out of 60 ... coverage = 0.19
# Placing sensor 8 out of 60 ... coverage = 0.21
# Placing sensor 9 out of 60 ... coverage = 0.22
# Placing sensor 10 out of 60 ... coverage = 0.23
# Placing sensor 11 out of 60 ... coverage = 0.24
# Placing sensor 12 out of 60 ... coverage = 0.26
# Placing sensor 13 out of 60 ... coverage = 0.27
# Placing sensor 14 out of 60 ... coverage = 0.28
# Placing sensor 15 out of 60 ... coverage = 0.29
# Placing sensor 16 out of 60 ... coverage = 0.30
# Placing sensor 17 out of 60 ... coverage = 0.31
# Placing sensor 18 out of 60 ... coverage = 0.32
# Placing sensor 19 out of 60 ... coverage = 0.33
# Placing sensor 20 out of 60 ... coverage = 0.34
# Placing sensor 21 out of 60 ... coverage = 0.34
# Placing sensor 22 out of 60 ... coverage = 0.35
# Placing sensor 23 out of 60 ... coverage = 0.36
# Placing sensor 24 out of 60 ... coverage = 0.37
# Placing sensor 25 out of 60 ... coverage = 0.37
# Placing sensor 26 out of 60 ... coverage = 0.38
# Placing sensor 27 out of 60 ... coverage = 0.39
# Placing sensor 28 out of 60 ... coverage = 0.39
# Placing sensor 29 out of 60 ... coverage = 0.40
# Placing sensor 30 out of 60 ... coverage = 0.41
# Placing sensor 31 out of 60 ... coverage = 0.41
# Placing sensor 32 out of 60 ... coverage = 0.42
# Placing sensor 33 out of 60 ... coverage = 0.42
# Placing sensor 34 out of 60 ... coverage = 0.43
# Placing sensor 35 out of 60 ... coverage = 0.43
# Placing sensor 36 out of 60 ... coverage = 0.44
# Placing sensor 37 out of 60 ... coverage = 0.44
# Placing sensor 38 out of 60 ... coverage = 0.45
# Placing sensor 39 out of 60 ... coverage = 0.45
# Placing sensor 40 out of 60 ... coverage = 0.46
# Placing sensor 41 out of 60 ... coverage = 0.46
# Placing sensor 42 out of 60 ... coverage = 0.47
# Placing sensor 43 out of 60 ... coverage = 0.47
# Placing sensor 44 out of 60 ... coverage = 0.48
# Placing sensor 45 out of 60 ... coverage = 0.48
# Placing sensor 46 out of 60 ... coverage = 0.48
# Placing sensor 47 out of 60 ... coverage = 0.49
# Placing sensor 48 out of 60 ... coverage = 0.49
# Placing sensor 49 out of 60 ... coverage = 0.50
# Placing sensor 50 out of 60 ... coverage = 0.50
# Placing sensor 51 out of 60 ... coverage = 0.50
# Placing sensor 52 out of 60 ... coverage = 0.51
# Placing sensor 53 out of 60 ... coverage = 0.51
# Placing sensor 54 out of 60 ... coverage = 0.51
# Placing sensor 55 out of 60 ... coverage = 0.52
# Placing sensor 56 out of 60 ... coverage = 0.52
# Placing sensor 57 out of 60 ... coverage = 0.52
# Placing sensor 58 out of 60 ... coverage = 0.53
# Placing sensor 59 out of 60 ... coverage = 0.53
# Placing sensor 60 out of 60 ... coverage = 0.53

# %% [markdown]
# ## Place of Work Only
#
# NB: Does using population weighted centroid make sense for workplace? Only alternative is to use OA (non-weighted) centroid. More complex for optimisation to use different locations for each one.

# %%
age_weights = 0
population_weight = 0
workplace_weight = 1

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/workplace_weights.png"
else:
    save_path = None
    
plot_oa_weights(weights, title="Weights: Number of Workers in OA",
                vmin=vmin, vmax=vmax,
                save_path=save_path)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/workplace_opt.png"
else:
    save_path = None

plot_optimisation_result(result,
                         save_path=save_path)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 60 ... coverage = 0.16
# Placing sensor 2 out of 60 ... coverage = 0.23
# Placing sensor 3 out of 60 ... coverage = 0.27
# Placing sensor 4 out of 60 ... coverage = 0.32
# Placing sensor 5 out of 60 ... coverage = 0.36
# Placing sensor 6 out of 60 ... coverage = 0.39
# Placing sensor 7 out of 60 ... coverage = 0.42
# Placing sensor 8 out of 60 ... coverage = 0.45
# Placing sensor 9 out of 60 ... coverage = 0.47
# Placing sensor 10 out of 60 ... coverage = 0.48
# Placing sensor 11 out of 60 ... coverage = 0.50
# Placing sensor 12 out of 60 ... coverage = 0.51
# Placing sensor 13 out of 60 ... coverage = 0.53
# Placing sensor 14 out of 60 ... coverage = 0.54
# Placing sensor 15 out of 60 ... coverage = 0.55
# Placing sensor 16 out of 60 ... coverage = 0.56
# Placing sensor 17 out of 60 ... coverage = 0.57
# Placing sensor 18 out of 60 ... coverage = 0.59
# Placing sensor 19 out of 60 ... coverage = 0.60
# Placing sensor 20 out of 60 ... coverage = 0.61
# Placing sensor 21 out of 60 ... coverage = 0.62
# Placing sensor 22 out of 60 ... coverage = 0.63
# Placing sensor 23 out of 60 ... coverage = 0.63
# Placing sensor 24 out of 60 ... coverage = 0.64
# Placing sensor 25 out of 60 ... coverage = 0.65
# Placing sensor 26 out of 60 ... coverage = 0.65
# Placing sensor 27 out of 60 ... coverage = 0.66
# Placing sensor 28 out of 60 ... coverage = 0.67
# Placing sensor 29 out of 60 ... coverage = 0.67
# Placing sensor 30 out of 60 ... coverage = 0.68
# Placing sensor 31 out of 60 ... coverage = 0.69
# Placing sensor 32 out of 60 ... coverage = 0.69
# Placing sensor 33 out of 60 ... coverage = 0.70
# Placing sensor 34 out of 60 ... coverage = 0.70
# Placing sensor 35 out of 60 ... coverage = 0.71
# Placing sensor 36 out of 60 ... coverage = 0.72
# Placing sensor 37 out of 60 ... coverage = 0.72
# Placing sensor 38 out of 60 ... coverage = 0.73
# Placing sensor 39 out of 60 ... coverage = 0.73
# Placing sensor 40 out of 60 ... coverage = 0.74
# Placing sensor 41 out of 60 ... coverage = 0.74
# Placing sensor 42 out of 60 ... coverage = 0.75
# Placing sensor 43 out of 60 ... coverage = 0.75
# Placing sensor 44 out of 60 ... coverage = 0.76
# Placing sensor 45 out of 60 ... coverage = 0.76
# Placing sensor 46 out of 60 ... coverage = 0.76
# Placing sensor 47 out of 60 ... coverage = 0.77
# Placing sensor 48 out of 60 ... coverage = 0.77
# Placing sensor 49 out of 60 ... coverage = 0.78
# Placing sensor 50 out of 60 ... coverage = 0.78
# Placing sensor 51 out of 60 ... coverage = 0.78
# Placing sensor 52 out of 60 ... coverage = 0.79
# Placing sensor 53 out of 60 ... coverage = 0.79
# Placing sensor 54 out of 60 ... coverage = 0.79
# Placing sensor 55 out of 60 ... coverage = 0.80
# Placing sensor 56 out of 60 ... coverage = 0.80
# Placing sensor 57 out of 60 ... coverage = 0.80
# Placing sensor 58 out of 60 ... coverage = 0.81
# Placing sensor 59 out of 60 ... coverage = 0.81
# Placing sensor 60 out of 60 ... coverage = 0.81

# %% [markdown]
# ## Children <12 Years Old Only

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index < 12] = 1

population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/children_weights.png"
else:
    save_path = None
    
plot_oa_weights(weights, title="Weights: Children <11 Years Old",
                vmin=vmin, vmax=vmax,
                save_path=save_path)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/children_opt.png"
else:
    save_path = None

plot_optimisation_result(result,
                         save_path=save_path)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 60 ... coverage = 0.06
# Placing sensor 2 out of 60 ... coverage = 0.09
# Placing sensor 3 out of 60 ... coverage = 0.11
# Placing sensor 4 out of 60 ... coverage = 0.14
# Placing sensor 5 out of 60 ... coverage = 0.16
# Placing sensor 6 out of 60 ... coverage = 0.18
# Placing sensor 7 out of 60 ... coverage = 0.20
# Placing sensor 8 out of 60 ... coverage = 0.22
# Placing sensor 9 out of 60 ... coverage = 0.23
# Placing sensor 10 out of 60 ... coverage = 0.25
# Placing sensor 11 out of 60 ... coverage = 0.26
# Placing sensor 12 out of 60 ... coverage = 0.27
# Placing sensor 13 out of 60 ... coverage = 0.29
# Placing sensor 14 out of 60 ... coverage = 0.30
# Placing sensor 15 out of 60 ... coverage = 0.31
# Placing sensor 16 out of 60 ... coverage = 0.32
# Placing sensor 17 out of 60 ... coverage = 0.33
# Placing sensor 18 out of 60 ... coverage = 0.34
# Placing sensor 19 out of 60 ... coverage = 0.35
# Placing sensor 20 out of 60 ... coverage = 0.36
# Placing sensor 21 out of 60 ... coverage = 0.37
# Placing sensor 22 out of 60 ... coverage = 0.37
# Placing sensor 23 out of 60 ... coverage = 0.38
# Placing sensor 24 out of 60 ... coverage = 0.39
# Placing sensor 25 out of 60 ... coverage = 0.40
# Placing sensor 26 out of 60 ... coverage = 0.40
# Placing sensor 27 out of 60 ... coverage = 0.41
# Placing sensor 28 out of 60 ... coverage = 0.42
# Placing sensor 29 out of 60 ... coverage = 0.42
# Placing sensor 30 out of 60 ... coverage = 0.43
# Placing sensor 31 out of 60 ... coverage = 0.43
# Placing sensor 32 out of 60 ... coverage = 0.44
# Placing sensor 33 out of 60 ... coverage = 0.45
# Placing sensor 34 out of 60 ... coverage = 0.45
# Placing sensor 35 out of 60 ... coverage = 0.46
# Placing sensor 36 out of 60 ... coverage = 0.46
# Placing sensor 37 out of 60 ... coverage = 0.47
# Placing sensor 38 out of 60 ... coverage = 0.47
# Placing sensor 39 out of 60 ... coverage = 0.48
# Placing sensor 40 out of 60 ... coverage = 0.48
# Placing sensor 41 out of 60 ... coverage = 0.49
# Placing sensor 42 out of 60 ... coverage = 0.49
# Placing sensor 43 out of 60 ... coverage = 0.49
# Placing sensor 44 out of 60 ... coverage = 0.50
# Placing sensor 45 out of 60 ... coverage = 0.50
# Placing sensor 46 out of 60 ... coverage = 0.51
# Placing sensor 47 out of 60 ... coverage = 0.51
# Placing sensor 48 out of 60 ... coverage = 0.51
# Placing sensor 49 out of 60 ... coverage = 0.52
# Placing sensor 50 out of 60 ... coverage = 0.52
# Placing sensor 51 out of 60 ... coverage = 0.53
# Placing sensor 52 out of 60 ... coverage = 0.53
# Placing sensor 53 out of 60 ... coverage = 0.53
# Placing sensor 54 out of 60 ... coverage = 0.54
# Placing sensor 55 out of 60 ... coverage = 0.54
# Placing sensor 56 out of 60 ... coverage = 0.54
# Placing sensor 57 out of 60 ... coverage = 0.55
# Placing sensor 58 out of 60 ... coverage = 0.55
# Placing sensor 59 out of 60 ... coverage = 0.55
# Placing sensor 60 out of 60 ... coverage = 0.56

# %% [markdown]
# ## Adults >65 Only

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index > 65] = 1

population_weight = 1
workplace_weight = 0

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/elderly_weights.png"
else:
    save_path = None

plot_oa_weights(weights, title="Weights: Adults >65 Years Old",
                vmin=vmin, vmax=vmax,
                save_path=save_path)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/elderly_opt.png"
else:
    save_path = None

plot_optimisation_result(result,
                         save_path=save_path)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 60 ... coverage = 0.03
# Placing sensor 2 out of 60 ... coverage = 0.06
# Placing sensor 3 out of 60 ... coverage = 0.08
# Placing sensor 4 out of 60 ... coverage = 0.11
# Placing sensor 5 out of 60 ... coverage = 0.13
# Placing sensor 6 out of 60 ... coverage = 0.14
# Placing sensor 7 out of 60 ... coverage = 0.16
# Placing sensor 8 out of 60 ... coverage = 0.18
# Placing sensor 9 out of 60 ... coverage = 0.19
# Placing sensor 10 out of 60 ... coverage = 0.21
# Placing sensor 11 out of 60 ... coverage = 0.22
# Placing sensor 12 out of 60 ... coverage = 0.23
# Placing sensor 13 out of 60 ... coverage = 0.25
# Placing sensor 14 out of 60 ... coverage = 0.26
# Placing sensor 15 out of 60 ... coverage = 0.27
# Placing sensor 16 out of 60 ... coverage = 0.28
# Placing sensor 17 out of 60 ... coverage = 0.29
# Placing sensor 18 out of 60 ... coverage = 0.30
# Placing sensor 19 out of 60 ... coverage = 0.31
# Placing sensor 20 out of 60 ... coverage = 0.32
# Placing sensor 21 out of 60 ... coverage = 0.33
# Placing sensor 22 out of 60 ... coverage = 0.34
# Placing sensor 23 out of 60 ... coverage = 0.34
# Placing sensor 24 out of 60 ... coverage = 0.35
# Placing sensor 25 out of 60 ... coverage = 0.36
# Placing sensor 26 out of 60 ... coverage = 0.37
# Placing sensor 27 out of 60 ... coverage = 0.37
# Placing sensor 28 out of 60 ... coverage = 0.38
# Placing sensor 29 out of 60 ... coverage = 0.39
# Placing sensor 30 out of 60 ... coverage = 0.39
# Placing sensor 31 out of 60 ... coverage = 0.40
# Placing sensor 32 out of 60 ... coverage = 0.40
# Placing sensor 33 out of 60 ... coverage = 0.41
# Placing sensor 34 out of 60 ... coverage = 0.42
# Placing sensor 35 out of 60 ... coverage = 0.42
# Placing sensor 36 out of 60 ... coverage = 0.43
# Placing sensor 37 out of 60 ... coverage = 0.43
# Placing sensor 38 out of 60 ... coverage = 0.44
# Placing sensor 39 out of 60 ... coverage = 0.44
# Placing sensor 40 out of 60 ... coverage = 0.45
# Placing sensor 41 out of 60 ... coverage = 0.45
# Placing sensor 42 out of 60 ... coverage = 0.46
# Placing sensor 43 out of 60 ... coverage = 0.46
# Placing sensor 44 out of 60 ... coverage = 0.46
# Placing sensor 45 out of 60 ... coverage = 0.47
# Placing sensor 46 out of 60 ... coverage = 0.47
# Placing sensor 47 out of 60 ... coverage = 0.48
# Placing sensor 48 out of 60 ... coverage = 0.48
# Placing sensor 49 out of 60 ... coverage = 0.49
# Placing sensor 50 out of 60 ... coverage = 0.49
# Placing sensor 51 out of 60 ... coverage = 0.49
# Placing sensor 52 out of 60 ... coverage = 0.50
# Placing sensor 53 out of 60 ... coverage = 0.50
# Placing sensor 54 out of 60 ... coverage = 0.51
# Placing sensor 55 out of 60 ... coverage = 0.51
# Placing sensor 56 out of 60 ... coverage = 0.51
# Placing sensor 57 out of 60 ... coverage = 0.52
# Placing sensor 58 out of 60 ... coverage = 0.52
# Placing sensor 59 out of 60 ... coverage = 0.52
# Placing sensor 60 out of 60 ... coverage = 0.53

# %% [markdown]
# ## Combined Weights, Varied by Age

# %%
age_weights = pd.Series(0, index=range(91))
age_weights[age_weights.index < 18] = 5
age_weights[age_weights.index < 12] = 10
age_weights[age_weights.index > 65] = 2
age_weights[age_weights.index > 75] = 5

plt.plot(age_weights)
plt.xlabel("Age")
plt.ylabel("Weight")

population_weight = 0.75
workplace_weight = 0.25

weights = calc_oa_weights(age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/mixed_weights.png"
else:
    save_path = None


plot_oa_weights(weights, title="75% Residential, 25% Workplace, Increased Weight Children & Elderly",
                vmin=vmin, vmax=vmax,
                save_path=save_path)

# %%
result = optimise(n_sensors=n_sensors,
                  theta=theta,
                  age_weights=age_weights,
                  population_weight=population_weight,
                  workplace_weight=workplace_weight)

if save:
    save_path = NB_DIR+"/../data/img/mixed_opt.png"
else:
    save_path = None

plot_optimisation_result(result,
                         save_path=save_path)
# Out:
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 60 ... coverage = 0.05
# Placing sensor 2 out of 60 ... coverage = 0.08
# Placing sensor 3 out of 60 ... coverage = 0.11
# Placing sensor 4 out of 60 ... coverage = 0.14
# Placing sensor 5 out of 60 ... coverage = 0.16
# Placing sensor 6 out of 60 ... coverage = 0.18
# Placing sensor 7 out of 60 ... coverage = 0.19
# Placing sensor 8 out of 60 ... coverage = 0.21
# Placing sensor 9 out of 60 ... coverage = 0.23
# Placing sensor 10 out of 60 ... coverage = 0.24
# Placing sensor 11 out of 60 ... coverage = 0.25
# Placing sensor 12 out of 60 ... coverage = 0.27
# Placing sensor 13 out of 60 ... coverage = 0.28
# Placing sensor 14 out of 60 ... coverage = 0.29
# Placing sensor 15 out of 60 ... coverage = 0.30
# Placing sensor 16 out of 60 ... coverage = 0.31
# Placing sensor 17 out of 60 ... coverage = 0.32
# Placing sensor 18 out of 60 ... coverage = 0.33
# Placing sensor 19 out of 60 ... coverage = 0.33
# Placing sensor 20 out of 60 ... coverage = 0.34
# Placing sensor 21 out of 60 ... coverage = 0.35
# Placing sensor 22 out of 60 ... coverage = 0.36
# Placing sensor 23 out of 60 ... coverage = 0.37
# Placing sensor 24 out of 60 ... coverage = 0.38
# Placing sensor 25 out of 60 ... coverage = 0.38
# Placing sensor 26 out of 60 ... coverage = 0.39
# Placing sensor 27 out of 60 ... coverage = 0.40
# Placing sensor 28 out of 60 ... coverage = 0.41
# Placing sensor 29 out of 60 ... coverage = 0.41
# Placing sensor 30 out of 60 ... coverage = 0.42
# Placing sensor 31 out of 60 ... coverage = 0.43
# Placing sensor 32 out of 60 ... coverage = 0.43
# Placing sensor 33 out of 60 ... coverage = 0.44
# Placing sensor 34 out of 60 ... coverage = 0.44
# Placing sensor 35 out of 60 ... coverage = 0.45
# Placing sensor 36 out of 60 ... coverage = 0.46
# Placing sensor 37 out of 60 ... coverage = 0.46
# Placing sensor 38 out of 60 ... coverage = 0.47
# Placing sensor 39 out of 60 ... coverage = 0.47
# Placing sensor 40 out of 60 ... coverage = 0.48
# Placing sensor 41 out of 60 ... coverage = 0.48
# Placing sensor 42 out of 60 ... coverage = 0.49
# Placing sensor 43 out of 60 ... coverage = 0.49
# Placing sensor 44 out of 60 ... coverage = 0.49
# Placing sensor 45 out of 60 ... coverage = 0.50
# Placing sensor 46 out of 60 ... coverage = 0.50
# Placing sensor 47 out of 60 ... coverage = 0.51
# Placing sensor 48 out of 60 ... coverage = 0.51
# Placing sensor 49 out of 60 ... coverage = 0.51
# Placing sensor 50 out of 60 ... coverage = 0.52
# Placing sensor 51 out of 60 ... coverage = 0.52
# Placing sensor 52 out of 60 ... coverage = 0.53
# Placing sensor 53 out of 60 ... coverage = 0.53
# Placing sensor 54 out of 60 ... coverage = 0.53
# Placing sensor 55 out of 60 ... coverage = 0.54
# Placing sensor 56 out of 60 ... coverage = 0.54
# Placing sensor 57 out of 60 ... coverage = 0.54
# Placing sensor 58 out of 60 ... coverage = 0.55
# Placing sensor 59 out of 60 ... coverage = 0.55
# Placing sensor 60 out of 60 ... coverage = 0.55

# %% [markdown]
# ## Loop: Const Age Weighting, Vary Workplace vs Residential

# %%
if save:
    for w in np.linspace(0, 1, 11):
        print("="*50)
        print("POP WEIGHT: ", w)
        print("="*50)

        age_weights = 1
        population_weight = w
        workplace_weight = 1-w

        title = "Weights: population={:.2f}, workplace={:.2f}".format(population_weight,
                                                                      workplace_weight)
        save_path = PLOT_DIR + "/pop_{:04d}_wplace_{:04d}".format(
                        int(1000*population_weight), int(1000*workplace_weight)
                    )

        weights = calc_oa_weights(age_weights=age_weights,
                                  population_weight=population_weight,
                                  workplace_weight=workplace_weight)

        plot_oa_weights(weights, title=title,
                        vmin=vmin, vmax=vmax,
                        save_path=save_path + "_WEIGHTS.png")

        result = optimise(n_sensors=n_sensors,
                          theta=theta,
                          age_weights=age_weights,
                          population_weight=population_weight,
                          workplace_weight=workplace_weight)

        plot_optimisation_result(result,
                                 title=title  + ", coverage={:.2f}".format(result["total_coverage"]),
                                 save_path=save_path + "_SENSORS.png")

        plt.close('all')
# Out:
# ==================================================
# POP WEIGHT:  0.0
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.16
# Placing sensor 2 out of 30 ... coverage = 0.23
# Placing sensor 3 out of 30 ... coverage = 0.27
# Placing sensor 4 out of 30 ... coverage = 0.32
# Placing sensor 5 out of 30 ... coverage = 0.36
# Placing sensor 6 out of 30 ... coverage = 0.39
# Placing sensor 7 out of 30 ... coverage = 0.42
# Placing sensor 8 out of 30 ... coverage = 0.45
# Placing sensor 9 out of 30 ... coverage = 0.47
# Placing sensor 10 out of 30 ... coverage = 0.48
# Placing sensor 11 out of 30 ... coverage = 0.50
# Placing sensor 12 out of 30 ... coverage = 0.51
# Placing sensor 13 out of 30 ... coverage = 0.53
# Placing sensor 14 out of 30 ... coverage = 0.54
# Placing sensor 15 out of 30 ... coverage = 0.55
# Placing sensor 16 out of 30 ... coverage = 0.56
# Placing sensor 17 out of 30 ... coverage = 0.57
# Placing sensor 18 out of 30 ... coverage = 0.59
# Placing sensor 19 out of 30 ... coverage = 0.60
# Placing sensor 20 out of 30 ... coverage = 0.61
# Placing sensor 21 out of 30 ... coverage = 0.62
# Placing sensor 22 out of 30 ... coverage = 0.63
# Placing sensor 23 out of 30 ... coverage = 0.63
# Placing sensor 24 out of 30 ... coverage = 0.64
# Placing sensor 25 out of 30 ... coverage = 0.65
# Placing sensor 26 out of 30 ... coverage = 0.65
# Placing sensor 27 out of 30 ... coverage = 0.66
# Placing sensor 28 out of 30 ... coverage = 0.67
# Placing sensor 29 out of 30 ... coverage = 0.67
# Placing sensor 30 out of 30 ... coverage = 0.68
# ==================================================
# POP WEIGHT:  0.1
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.15
# Placing sensor 2 out of 30 ... coverage = 0.21
# Placing sensor 3 out of 30 ... coverage = 0.25
# Placing sensor 4 out of 30 ... coverage = 0.29
# Placing sensor 5 out of 30 ... coverage = 0.33
# Placing sensor 6 out of 30 ... coverage = 0.36
# Placing sensor 7 out of 30 ... coverage = 0.39
# Placing sensor 8 out of 30 ... coverage = 0.41
# Placing sensor 9 out of 30 ... coverage = 0.43
# Placing sensor 10 out of 30 ... coverage = 0.45
# Placing sensor 11 out of 30 ... coverage = 0.46
# Placing sensor 12 out of 30 ... coverage = 0.48
# Placing sensor 13 out of 30 ... coverage = 0.49
# Placing sensor 14 out of 30 ... coverage = 0.50
# Placing sensor 15 out of 30 ... coverage = 0.51
# Placing sensor 16 out of 30 ... coverage = 0.53
# Placing sensor 17 out of 30 ... coverage = 0.54
# Placing sensor 18 out of 30 ... coverage = 0.55
# Placing sensor 19 out of 30 ... coverage = 0.56
# Placing sensor 20 out of 30 ... coverage = 0.57
# Placing sensor 21 out of 30 ... coverage = 0.58
# Placing sensor 22 out of 30 ... coverage = 0.58
# Placing sensor 23 out of 30 ... coverage = 0.59
# Placing sensor 24 out of 30 ... coverage = 0.60
# Placing sensor 25 out of 30 ... coverage = 0.61
# Placing sensor 26 out of 30 ... coverage = 0.61
# Placing sensor 27 out of 30 ... coverage = 0.62
# Placing sensor 28 out of 30 ... coverage = 0.63
# Placing sensor 29 out of 30 ... coverage = 0.63
# Placing sensor 30 out of 30 ... coverage = 0.64
# ==================================================
# POP WEIGHT:  0.2
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.13
# Placing sensor 2 out of 30 ... coverage = 0.19
# Placing sensor 3 out of 30 ... coverage = 0.23
# Placing sensor 4 out of 30 ... coverage = 0.27
# Placing sensor 5 out of 30 ... coverage = 0.30
# Placing sensor 6 out of 30 ... coverage = 0.33
# Placing sensor 7 out of 30 ... coverage = 0.35
# Placing sensor 8 out of 30 ... coverage = 0.38
# Placing sensor 9 out of 30 ... coverage = 0.40
# Placing sensor 10 out of 30 ... coverage = 0.41
# Placing sensor 11 out of 30 ... coverage = 0.43
# Placing sensor 12 out of 30 ... coverage = 0.44
# Placing sensor 13 out of 30 ... coverage = 0.45
# Placing sensor 14 out of 30 ... coverage = 0.46
# Placing sensor 15 out of 30 ... coverage = 0.48
# Placing sensor 16 out of 30 ... coverage = 0.49
# Placing sensor 17 out of 30 ... coverage = 0.50
# Placing sensor 18 out of 30 ... coverage = 0.51
# Placing sensor 19 out of 30 ... coverage = 0.52
# Placing sensor 20 out of 30 ... coverage = 0.53
# Placing sensor 21 out of 30 ... coverage = 0.54
# Placing sensor 22 out of 30 ... coverage = 0.54
# Placing sensor 23 out of 30 ... coverage = 0.55
# Placing sensor 24 out of 30 ... coverage = 0.56
# Placing sensor 25 out of 30 ... coverage = 0.56
# Placing sensor 26 out of 30 ... coverage = 0.57
# Placing sensor 27 out of 30 ... coverage = 0.58
# Placing sensor 28 out of 30 ... coverage = 0.58
# Placing sensor 29 out of 30 ... coverage = 0.59
# Placing sensor 30 out of 30 ... coverage = 0.60
# ==================================================
# POP WEIGHT:  0.30000000000000004
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.12
# Placing sensor 2 out of 30 ... coverage = 0.17
# Placing sensor 3 out of 30 ... coverage = 0.21
# Placing sensor 4 out of 30 ... coverage = 0.24
# Placing sensor 5 out of 30 ... coverage = 0.28
# Placing sensor 6 out of 30 ... coverage = 0.30
# Placing sensor 7 out of 30 ... coverage = 0.32
# Placing sensor 8 out of 30 ... coverage = 0.34
# Placing sensor 9 out of 30 ... coverage = 0.36
# Placing sensor 10 out of 30 ... coverage = 0.38
# Placing sensor 11 out of 30 ... coverage = 0.39
# Placing sensor 12 out of 30 ... coverage = 0.41
# Placing sensor 13 out of 30 ... coverage = 0.42
# Placing sensor 14 out of 30 ... coverage = 0.43
# Placing sensor 15 out of 30 ... coverage = 0.44
# Placing sensor 16 out of 30 ... coverage = 0.45
# Placing sensor 17 out of 30 ... coverage = 0.46
# Placing sensor 18 out of 30 ... coverage = 0.47
# Placing sensor 19 out of 30 ... coverage = 0.48
# Placing sensor 20 out of 30 ... coverage = 0.49
# Placing sensor 21 out of 30 ... coverage = 0.50
# Placing sensor 22 out of 30 ... coverage = 0.51
# Placing sensor 23 out of 30 ... coverage = 0.51
# Placing sensor 24 out of 30 ... coverage = 0.52
# Placing sensor 25 out of 30 ... coverage = 0.53
# Placing sensor 26 out of 30 ... coverage = 0.53
# Placing sensor 27 out of 30 ... coverage = 0.54
# Placing sensor 28 out of 30 ... coverage = 0.55
# Placing sensor 29 out of 30 ... coverage = 0.55
# Placing sensor 30 out of 30 ... coverage = 0.56
# ==================================================
# POP WEIGHT:  0.4
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.11
# Placing sensor 2 out of 30 ... coverage = 0.15
# Placing sensor 3 out of 30 ... coverage = 0.19
# Placing sensor 4 out of 30 ... coverage = 0.22
# Placing sensor 5 out of 30 ... coverage = 0.25
# Placing sensor 6 out of 30 ... coverage = 0.27
# Placing sensor 7 out of 30 ... coverage = 0.29
# Placing sensor 8 out of 30 ... coverage = 0.31
# Placing sensor 9 out of 30 ... coverage = 0.33
# Placing sensor 10 out of 30 ... coverage = 0.34
# Placing sensor 11 out of 30 ... coverage = 0.36
# Placing sensor 12 out of 30 ... coverage = 0.37
# Placing sensor 13 out of 30 ... coverage = 0.38
# Placing sensor 14 out of 30 ... coverage = 0.40
# Placing sensor 15 out of 30 ... coverage = 0.41
# Placing sensor 16 out of 30 ... coverage = 0.42
# Placing sensor 17 out of 30 ... coverage = 0.43
# Placing sensor 18 out of 30 ... coverage = 0.44
# Placing sensor 19 out of 30 ... coverage = 0.44
# Placing sensor 20 out of 30 ... coverage = 0.45
# Placing sensor 21 out of 30 ... coverage = 0.46
# Placing sensor 22 out of 30 ... coverage = 0.47
# Placing sensor 23 out of 30 ... coverage = 0.48
# Placing sensor 24 out of 30 ... coverage = 0.48
# Placing sensor 25 out of 30 ... coverage = 0.49
# Placing sensor 26 out of 30 ... coverage = 0.50
# Placing sensor 27 out of 30 ... coverage = 0.51
# Placing sensor 28 out of 30 ... coverage = 0.51
# Placing sensor 29 out of 30 ... coverage = 0.52
# Placing sensor 30 out of 30 ... coverage = 0.52
# ==================================================
# POP WEIGHT:  0.5
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.10
# Placing sensor 2 out of 30 ... coverage = 0.13
# Placing sensor 3 out of 30 ... coverage = 0.17
# Placing sensor 4 out of 30 ... coverage = 0.20
# Placing sensor 5 out of 30 ... coverage = 0.22
# Placing sensor 6 out of 30 ... coverage = 0.25
# Placing sensor 7 out of 30 ... coverage = 0.26
# Placing sensor 8 out of 30 ... coverage = 0.28
# Placing sensor 9 out of 30 ... coverage = 0.30
# Placing sensor 10 out of 30 ... coverage = 0.31
# Placing sensor 11 out of 30 ... coverage = 0.32
# Placing sensor 12 out of 30 ... coverage = 0.34
# Placing sensor 13 out of 30 ... coverage = 0.35
# Placing sensor 14 out of 30 ... coverage = 0.36
# Placing sensor 15 out of 30 ... coverage = 0.37
# Placing sensor 16 out of 30 ... coverage = 0.39
# Placing sensor 17 out of 30 ... coverage = 0.40
# Placing sensor 18 out of 30 ... coverage = 0.41
# Placing sensor 19 out of 30 ... coverage = 0.41
# Placing sensor 20 out of 30 ... coverage = 0.42
# Placing sensor 21 out of 30 ... coverage = 0.43
# Placing sensor 22 out of 30 ... coverage = 0.44
# Placing sensor 23 out of 30 ... coverage = 0.45
# Placing sensor 24 out of 30 ... coverage = 0.45
# Placing sensor 25 out of 30 ... coverage = 0.46
# Placing sensor 26 out of 30 ... coverage = 0.47
# Placing sensor 27 out of 30 ... coverage = 0.47
# Placing sensor 28 out of 30 ... coverage = 0.48
# Placing sensor 29 out of 30 ... coverage = 0.48
# Placing sensor 30 out of 30 ... coverage = 0.49
# ==================================================
# POP WEIGHT:  0.6000000000000001
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.08
# Placing sensor 2 out of 30 ... coverage = 0.11
# Placing sensor 3 out of 30 ... coverage = 0.15
# Placing sensor 4 out of 30 ... coverage = 0.17
# Placing sensor 5 out of 30 ... coverage = 0.20
# Placing sensor 6 out of 30 ... coverage = 0.22
# Placing sensor 7 out of 30 ... coverage = 0.24
# Placing sensor 8 out of 30 ... coverage = 0.25
# Placing sensor 9 out of 30 ... coverage = 0.27
# Placing sensor 10 out of 30 ... coverage = 0.28
# Placing sensor 11 out of 30 ... coverage = 0.29
# Placing sensor 12 out of 30 ... coverage = 0.31
# Placing sensor 13 out of 30 ... coverage = 0.32
# Placing sensor 14 out of 30 ... coverage = 0.33
# Placing sensor 15 out of 30 ... coverage = 0.34
# Placing sensor 16 out of 30 ... coverage = 0.35
# Placing sensor 17 out of 30 ... coverage = 0.36
# Placing sensor 18 out of 30 ... coverage = 0.37
# Placing sensor 19 out of 30 ... coverage = 0.38
# Placing sensor 20 out of 30 ... coverage = 0.39
# Placing sensor 21 out of 30 ... coverage = 0.40
# Placing sensor 22 out of 30 ... coverage = 0.41
# Placing sensor 23 out of 30 ... coverage = 0.42
# Placing sensor 24 out of 30 ... coverage = 0.42
# Placing sensor 25 out of 30 ... coverage = 0.43
# Placing sensor 26 out of 30 ... coverage = 0.44
# Placing sensor 27 out of 30 ... coverage = 0.44
# Placing sensor 28 out of 30 ... coverage = 0.45
# Placing sensor 29 out of 30 ... coverage = 0.46
# Placing sensor 30 out of 30 ... coverage = 0.46
# ==================================================
# POP WEIGHT:  0.7000000000000001
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.07
# Placing sensor 2 out of 30 ... coverage = 0.10
# Placing sensor 3 out of 30 ... coverage = 0.12
# Placing sensor 4 out of 30 ... coverage = 0.15
# Placing sensor 5 out of 30 ... coverage = 0.17
# Placing sensor 6 out of 30 ... coverage = 0.19
# Placing sensor 7 out of 30 ... coverage = 0.21
# Placing sensor 8 out of 30 ... coverage = 0.23
# Placing sensor 9 out of 30 ... coverage = 0.24
# Placing sensor 10 out of 30 ... coverage = 0.26
# Placing sensor 11 out of 30 ... coverage = 0.27
# Placing sensor 12 out of 30 ... coverage = 0.28
# Placing sensor 13 out of 30 ... coverage = 0.30
# Placing sensor 14 out of 30 ... coverage = 0.31
# Placing sensor 15 out of 30 ... coverage = 0.32
# Placing sensor 16 out of 30 ... coverage = 0.33
# Placing sensor 17 out of 30 ... coverage = 0.34
# Placing sensor 18 out of 30 ... coverage = 0.35
# Placing sensor 19 out of 30 ... coverage = 0.36
# Placing sensor 20 out of 30 ... coverage = 0.36
# Placing sensor 21 out of 30 ... coverage = 0.37
# Placing sensor 22 out of 30 ... coverage = 0.38
# Placing sensor 23 out of 30 ... coverage = 0.39
# Placing sensor 24 out of 30 ... coverage = 0.40
# Placing sensor 25 out of 30 ... coverage = 0.40
# Placing sensor 26 out of 30 ... coverage = 0.41
# Placing sensor 27 out of 30 ... coverage = 0.42
# Placing sensor 28 out of 30 ... coverage = 0.43
# Placing sensor 29 out of 30 ... coverage = 0.43
# Placing sensor 30 out of 30 ... coverage = 0.44
# ==================================================
# POP WEIGHT:  0.8
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.06
# Placing sensor 2 out of 30 ... coverage = 0.09
# Placing sensor 3 out of 30 ... coverage = 0.11
# Placing sensor 4 out of 30 ... coverage = 0.14
# Placing sensor 5 out of 30 ... coverage = 0.16
# Placing sensor 6 out of 30 ... coverage = 0.18
# Placing sensor 7 out of 30 ... coverage = 0.19
# Placing sensor 8 out of 30 ... coverage = 0.21
# Placing sensor 9 out of 30 ... coverage = 0.22
# Placing sensor 10 out of 30 ... coverage = 0.24
# Placing sensor 11 out of 30 ... coverage = 0.25
# Placing sensor 12 out of 30 ... coverage = 0.27
# Placing sensor 13 out of 30 ... coverage = 0.28
# Placing sensor 14 out of 30 ... coverage = 0.29
# Placing sensor 15 out of 30 ... coverage = 0.30
# Placing sensor 16 out of 30 ... coverage = 0.31
# Placing sensor 17 out of 30 ... coverage = 0.32
# Placing sensor 18 out of 30 ... coverage = 0.33
# Placing sensor 19 out of 30 ... coverage = 0.34
# Placing sensor 20 out of 30 ... coverage = 0.34
# Placing sensor 21 out of 30 ... coverage = 0.35
# Placing sensor 22 out of 30 ... coverage = 0.36
# Placing sensor 23 out of 30 ... coverage = 0.37
# Placing sensor 24 out of 30 ... coverage = 0.38
# Placing sensor 25 out of 30 ... coverage = 0.38
# Placing sensor 26 out of 30 ... coverage = 0.39
# Placing sensor 27 out of 30 ... coverage = 0.40
# Placing sensor 28 out of 30 ... coverage = 0.41
# Placing sensor 29 out of 30 ... coverage = 0.41
# Placing sensor 30 out of 30 ... coverage = 0.42
# ==================================================
# POP WEIGHT:  0.9
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.04
# Placing sensor 2 out of 30 ... coverage = 0.07
# Placing sensor 3 out of 30 ... coverage = 0.10
# Placing sensor 4 out of 30 ... coverage = 0.12
# Placing sensor 5 out of 30 ... coverage = 0.15
# Placing sensor 6 out of 30 ... coverage = 0.17
# Placing sensor 7 out of 30 ... coverage = 0.18
# Placing sensor 8 out of 30 ... coverage = 0.20
# Placing sensor 9 out of 30 ... coverage = 0.21
# Placing sensor 10 out of 30 ... coverage = 0.23
# Placing sensor 11 out of 30 ... coverage = 0.24
# Placing sensor 12 out of 30 ... coverage = 0.25
# Placing sensor 13 out of 30 ... coverage = 0.26
# Placing sensor 14 out of 30 ... coverage = 0.28
# Placing sensor 15 out of 30 ... coverage = 0.29
# Placing sensor 16 out of 30 ... coverage = 0.30
# Placing sensor 17 out of 30 ... coverage = 0.30
# Placing sensor 18 out of 30 ... coverage = 0.31
# Placing sensor 19 out of 30 ... coverage = 0.32
# Placing sensor 20 out of 30 ... coverage = 0.33
# Placing sensor 21 out of 30 ... coverage = 0.34
# Placing sensor 22 out of 30 ... coverage = 0.35
# Placing sensor 23 out of 30 ... coverage = 0.36
# Placing sensor 24 out of 30 ... coverage = 0.36
# Placing sensor 25 out of 30 ... coverage = 0.37
# Placing sensor 26 out of 30 ... coverage = 0.38
# Placing sensor 27 out of 30 ... coverage = 0.39
# Placing sensor 28 out of 30 ... coverage = 0.39
# Placing sensor 29 out of 30 ... coverage = 0.40
# Placing sensor 30 out of 30 ... coverage = 0.41
# ==================================================
# POP WEIGHT:  1.0
# ==================================================
# Setting up jobs and sockets...
# Fetching data...
# Placing sensor 1 out of 30 ... coverage = 0.04
# Placing sensor 2 out of 30 ... coverage = 0.08
# Placing sensor 3 out of 30 ... coverage = 0.10
# Placing sensor 4 out of 30 ... coverage = 0.12
# Placing sensor 5 out of 30 ... coverage = 0.15
# Placing sensor 6 out of 30 ... coverage = 0.17
# Placing sensor 7 out of 30 ... coverage = 0.19
# Placing sensor 8 out of 30 ... coverage = 0.21
# Placing sensor 9 out of 30 ... coverage = 0.22
# Placing sensor 10 out of 30 ... coverage = 0.23
# Placing sensor 11 out of 30 ... coverage = 0.24
# Placing sensor 12 out of 30 ... coverage = 0.26
# Placing sensor 13 out of 30 ... coverage = 0.27
# Placing sensor 14 out of 30 ... coverage = 0.28
# Placing sensor 15 out of 30 ... coverage = 0.29
# Placing sensor 16 out of 30 ... coverage = 0.30
# Placing sensor 17 out of 30 ... coverage = 0.31
# Placing sensor 18 out of 30 ... coverage = 0.32
# Placing sensor 19 out of 30 ... coverage = 0.33
# Placing sensor 20 out of 30 ... coverage = 0.34
# Placing sensor 21 out of 30 ... coverage = 0.34
# Placing sensor 22 out of 30 ... coverage = 0.35
# Placing sensor 23 out of 30 ... coverage = 0.36
# Placing sensor 24 out of 30 ... coverage = 0.37
# Placing sensor 25 out of 30 ... coverage = 0.37
# Placing sensor 26 out of 30 ... coverage = 0.38
# Placing sensor 27 out of 30 ... coverage = 0.39
# Placing sensor 28 out of 30 ... coverage = 0.39
# Placing sensor 29 out of 30 ... coverage = 0.40
# Placing sensor 30 out of 30 ... coverage = 0.41
